# %%
#importing class 
from utils import  FFR_graphs

#initializing class "FFR__graphs"
graphs = FFR_graphs()
# Out:
# 1 Failed download:
# - ZQZ22.CBT: No data found, symbol may be delisted

# %%
#first use case
#shows the historical implied fed funds rate based on futures contracts 


graphs.hist_exp("2022-01-01", "2022-12-25", 3)
#historical values of the FED FUNDS RATE futures prices from "start_dt" to "end_dt" with a period of "period" days

# %%
#second use case 
#shows the shifts in the expected fed funds rate trajectories looking forward in time 


#Implied FED FUNDS RATE trajectories from "start_dt" to "end_dt" with a period of "period" days 

graphs.impl_exp("2022-10-18", "2022-12-15", 10)

# %%
#third use case 
#shows the immediate shifts  in the expected fed funds rate trajectories looking forward in time after FOMC meetings

#fomc meeting date in this example is 2022-06-15, so we took start_dt 10 days prior and end date 15 days later


graphs.impl_exp("2022-06-05", "2022-06-30", 7)
